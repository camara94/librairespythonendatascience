# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from math import exp, sqrt, pi

# %%
domaine = range(-100, 100)
mu = 0
sigma = 20
f = lambda x:1/(sqrt(2*pi*pow(sigma, 2))) * exp(-pow((x-mu), 2) /(2*pow(sigma,2)) )
y = [f(x) for x in domaine]
plot = plt.plot(domaine, y)

# %%
vecteur_aleatoire = np.random.rand(30)

# %%
plt.scatter(range(30), vecteur_aleatoire)

# %%
matrix_aleatoire = np.random.rand(3,5)

# %%
matrix_aleatoire
# Out:
# array([[0.94704141, 0.11056458, 0.70400244, 0.86534035, 0.89586958],
#        [0.35171174, 0.55218949, 0.90084296, 0.90053278, 0.2785722 ],
#        [0.56745542, 0.54575445, 0.11903601, 0.12083193, 0.16347494]])

# %%
matrix = np.random.rand(100, 200)

# %%
np.sum(matrix)
# Out:
# 10008.22367529371

# %%
somme = np.sum(matrix, 0)

# %%
somme.shape
# Out:
# (200,)

# %%
plt.scatter(range(200), somme)

# %%
plt.hist(somme)
# Out:
# (array([ 1.,  3.,  6., 15., 47., 45., 35., 33., 12.,  3.]),
#  array([40.04608805, 41.8061298 , 43.56617155, 45.3262133 , 47.08625505,
#         48.8462968 , 50.60633855, 52.3663803 , 54.12642205, 55.8864638 ,
#         57.64650555]),
#  <a list of 10 Patch objects>)

# %%
matrice = np.random.rand(1000, 10000)

# %%
somme = np.sum(matrice,0)

# %%
somme.shape
# Out:
# (10000,)

# %%
plot = plt.hist(somme, bins=100)

# %%
def puissance(n, i):
    return n**i

# %%
puissance(4,2)
# Out:
# 16

# %%
def loi_normale(x, mu, sigma):
    return 1/(sqrt(2*pi*puissance(sigma, 2)) * exp((pow((x-mu), 2))/(2*pow(sigma, 2))))

# %%
domaine = range(-100, 100);
mu = 0
sigma = 15

y = [loi_normale(x, mu, sigma) for x in domaine]

# %%
plt.plot(domaine, y)
plt.xlabel('domaine')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
